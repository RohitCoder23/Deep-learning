# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from skimage.io import imread, imshow

image = imread('/content/cat3.jpg', as_gray=True)
imshow(image)

# %%
print(image.shape)
print( image)
# Out:
# (146, 345)
# [[0.94901961 0.9372549  0.9254902  ... 0.02684784 0.02684784 0.03861255]
#  [0.97059961 0.96275647 0.95686275 ... 0.03076941 0.03076941 0.03861255]
#  [0.97620275 0.96835961 0.97228118 ... 0.03861255 0.03861255 0.04645569]
#  ...
#  [0.60592863 0.61320627 0.62497098 ... 0.20573608 0.20573608 0.20573608]
#  [0.6797102  0.67522314 0.67408431 ... 0.20181451 0.20181451 0.20573608]
#  [0.6914749  0.68306627 0.67800588 ... 0.20181451 0.20181451 0.20573608]]

# %%
image = imread('/content/cat3.jpg', as_gray=True) 
print("Image shape: ",image.shape)

print( imshow(image))
# we print the gray image
# Out:
# (146, 345)
# AxesImage(36.925,10.8;384.275x266.4)

# %%
a,b=image.shape
# Out:
# 146
# 345

# %%
#pixel features
features = np.reshape(image, (a*b))  

features.shape, features
# Out:
# ((50370,),
#  array([0.94901961, 0.9372549 , 0.9254902 , ..., 0.20181451, 0.20181451,
#         0.20573608]))

# %%
#Machines store images in the form of a matrix of numbers. The size of this matrix depends on the number of pixels we have in any given image.

# %%
#the pixel values, denote the intensity or brightness of the pixel. Smaller numbers (closer to zero) represent black, and larger numbers (closer to 255) denote white

# %%
#he simplest way to create features from an image 
#is to use these raw pixel values as separate features.

#Consider the same example for our image above (the number ‘8’) – the dimension of the image is 28 x 28.

#The number of features will be the same as the number of pixels! Hence, that number will be 784
