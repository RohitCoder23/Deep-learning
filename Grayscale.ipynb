# %%
from PIL import Image

img = Image.open('/content/cat4.jpg')
imgGray = img.convert('L')
imgGray.save('test_gray.jpg')

# %%
imgGray
# Out:
# <PIL.Image.Image image mode=L size=275x183 at 0x7F2E42B49C10>
