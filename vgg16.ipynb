# %%
import tensorflow as tf
from tensorflow.keras import layers,models,datasets
from tensorflow.keras.applications.vgg16 import VGG16
import matplotlib.pyplot as plt

(train_images,train_labels),(test_images,test_labels)=datasets.cifar100.load_data()
train_images=train_images/255
test_images=test_images/255

base=VGG16(include_top=False,input_shape=(32,32,3))
base.trainable=False
model=models.Sequential()
model.add(layers.Flatten())
model.add(layers.Dense(1200,activation="relu"))
model.add(layers.Dense(100,activation="softmax"))
model.compile(optimizer="adam",loss="sparse_categorical_crossentropy",metrics=
["accuracy"])
history=model.fit(train_images,train_labels,epochs=10,validation_data=(test_images,test_labels),steps_per_epoch=200)

plt.plot(history.history['loss'])

plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
plt.plot(history.history['val_loss'])
plt.show()
plt.plot(history.history['accuracy'])

plt.show()
# Out:
# Epoch 1/10
# 200/200 [==============================] - 14s 71ms/step - loss: 4.1589 - accuracy: 0.0785 - val_loss: 3.8622 - val_accuracy: 0.1169
# Epoch 2/10
# 200/200 [==============================] - 14s 71ms/step - loss: 3.7342 - accuracy: 0.1388 - val_loss: 3.6684 - val_accuracy: 0.1515
# Epoch 3/10
# 200/200 [==============================] - 14s 70ms/step - loss: 3.5833 - accuracy: 0.1652 - val_loss: 3.5907 - val_accuracy: 0.1646
# Epoch 4/10
# 200/200 [==============================] - 14s 70ms/step - loss: 3.4836 - accuracy: 0.1842 - val_loss: 3.5031 - val_accuracy: 0.1885
# Epoch 5/10
# 200/200 [==============================] - 14s 70ms/step - loss: 3.4118 - accuracy: 0.1970 - val_loss: 3.4871 - val_accuracy: 0.1892
# Epoch 6/10
# 200/200 [==============================] - 14s 70ms/step - loss: 3.3352 - accuracy: 0.2118 - val_loss: 3.4376 - val_accuracy: 0.1953
# Epoch 7/10
# ...
